# %%
import numpy as np
import matplotlib.pyplot as plt
import os

directory = "/home/ariel/lorenzo.mugnai/USER_DATA/Alfnoor2/20250226 - NAOJ/20250723/forwards/ArielInstrumentTier2"
subfolders = [name for name in os.listdir(directory) if os.path.isdir(os.path.join(directory, name))]

print(subfolders)

len(subfolders)
# Out:
# ['TOI-2076bMig', 'TOI-1064cFidu', 'K2-138fMig', 'TOI-1266bMigR', 'HD191939dFiduR', 'TOI-2427bMigR', 'TOI-712bFiduR', 'TOI-4438bFidu', 'HD3167cMig', 'piMencMig', 'HD63935bFiduR', 'HD86226cMig', 'HD191939dMigR', 'TOI-544bFidu', 'TOI-913bMigR', 'TOI-2136bMigR', 'HD15906cFiduR', 'Kepler-102eFiduR', 'HD108236eMigR', 'TOI-431dMigR', 'HD93963AcMig', 'TOI-1201bMigR', 'TOI-1136eFiduR', 'Wolf503bFiduR', 'TOI-277bMig', 'TOI-663bMigR', 'K2-32dFiduR', 'HD110067fFidu', 'TOI-1470cFidu', 'HD15337cFiduR', 'HD109833bMigR', 'TOI-2459bMigR', 'K2-36cMigR', 'TOI-269bFiduR', 'K2-155cFidu', 'HD73583bMigR', 'TOI-1136gMigR', 'TOI-178dMigR', 'TOI-4438bFiduR', 'TOI-1246bFidu', 'TOI-815bFidu', 'GJ1214bFiduR', 'TOI-125bFidu', 'TOI-1064cMig', 'Wolf503bFidu', 'TOI-776cFiduR', 'HD110113bFiduR', 'K2-138gMigR', 'TOI-4479bFidu', 'HD86226cFiduR', 'K2-138fMigR', 'HIP94235bMigR', 'K2-32cFidu', 'TOI-712bMigR', 'TOI-904bFiduR', 'TOI-4438bMig', 'TOI-5704bMigR', 'TOI-1759bFidu', 'HD93963AcFiduR', 'GJ3090bFidu', 'TOI-270dMig', 'TOI-178dMig', 'HD191939cFidu', 'HD191939dFidu', 'HD110067cMig', 'TOI-2076cMigR', 'HD108236eFidu', 'HD110067dMig', 'HD93963AcMigR', 'TOI-125bMigR', 'HD28109dFidu', 'HD63433cFidu', 'TOI-4336AbMigR', 'TOI-270cMig', 'TOI-178gFidu', 'TOI-1260dMig', 'K2-155cMig', 'TOI-700cMigR', 'TOI-2018bFidu', 'HD28109dMig', 'K2-26bMig', 'TOI-815bMig', 'GJ3090bFiduR', 'GJ1214bMigR', 'TOI-561cFidu', 'TOI-125cMigR', 'K2-138gFidu', 'TOI-4479bMig', 'TOI-2120bMigR', 'TOI-421bMig', 'TOI-1201bMig', 'TOI-1801bFidu', 'LTT3780cFidu', 'Kepler-109cFidu', 'TOI-1470cMigR', 'TOI-451cMig', 'TOI-663cMigR', 'TOI-561cMig', 'HD109833bFiduR', 'GJ3090bMigR', 'TOI-904bFidu', 'TOI-2459bFidu', 'TOI-2018bMigR', 'HD110067fFiduR', 'K2-3bMigR', 'TOI-5704bFidu
ig', 'TOI-1266cMig', 'piMencFiduR', 'HD23472cMig', 'TOI-1246bFiduR', 'TOI-444bMigR', 'HD63433bFiduR', 'HD110067dFiduR', 'TOI-4010bFidu', 'HD110067bFidu', 'Kepler-102eMigR', 'Kepler-102eFidu', 'TOI-1470bMigR', 'TOI-2459bMig', 'HD63433bMigR', 'TOI-663bFiduR', 'HD191939bFidu', 'HD191939cFiduR', 'TOI-1470bFidu', 'TOI-270dFidu', 'HD191939dMig', 'TOI-5 ...
# 414

# %%
# check failed
from astropy.io import ascii


targetlist = ascii.read("/home/ariel/lorenzo.mugnai/USER_DATA/Alfnoor2/20250226 - NAOJ/20250723/20250721_ArielTargetSimul_Metadata.csv")

directory_t3 = "/home/ariel/lorenzo.mugnai/USER_DATA/Alfnoor2/20250226 - NAOJ/20250723/forwards/ArielInstrumentTier3"
subfolders_check = [name for name in os.listdir(directory) if os.path.isdir(os.path.join(directory, name)) 
                    and os.path.exists(os.path.join(os.path.join(directory, name), name+".txt"))]


idx = [i for i, name in enumerate(targetlist["Planet Name"]) if name not in subfolders_check]
missing_planets = targetlist[idx]

print(missing_planets["Planet Name"])
print(len(missing_planets))
# ascii.write(missing_planets, "missing_planets.csv", format='csv', overwrite=True)
# Out:
#  Planet Name
# --------------
#    TOI-776bMig
#     K2-417bMig
#   TOI-2015bMig
#      K2-25bMig
# TOI-5704bFiduR
#   K2-155cFiduR
# TOI-5803bFiduR
#    55CnceFiduR
#  TOI-815bFiduR
# TOI-2076cFiduR
#            ...
#  TOI-431dFiduR
# TOI-1064cFiduR
#  TOI-836cFiduR
# TOI-2459bFiduR
# TOI-2443bFiduR
#    K2-36cFiduR
#  HD73583bFiduR
#  TOI-178dFiduR
#  TOI-544bFiduR
# HD110067bFiduR
# HD110067cFiduR
# Length = 46 rows
# 46

# %%
import t
for file_ in subfolders:
    fig = plt.figure(figsize=(10, 6))
    data = np.loadtxt("forwards/ArielInstrumentTier2/" + file_ + "/" + file_ + ".txt").T
    plt.title(file_)
    plt.errorbar(data[0], data[1], yerr=data[2], alpha=0.5, label=file_)
    plt.xlim(1.2, 4)
    plt.savefig("plots/" + file_ + "_t2.png")


fig = plt.figure(figsize=(10, 6))
for file_ in subfolders:
    data = np.loadtxt('forwards/ArielInstrumentTier2/'+file_+'/'+file_+'.txt').T
    plt.errorbar(data[0], data[1], yerr=data[2], alpha=0.5, label=file_)

# plt.legend()
plt.xlim(1.2, 4)
# Out:
# /tmp/ipykernel_303581/1875375865.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig
335.0, 15.0, 8.0, 19.0, 362.0, 64.0, 180.0, 35.0, 483.0, 61.0, 6.0, 149.0, 118.0, 1150.0, 131.0, 224.0, 923.0, 89.0, 666.0, 219.0, 25.0, 341.0, 76.0, 45.0, 72.0, 362.0, 1631.0, 96.0, 19.0, 1326.0, 163.0, 195.0, 75.0, 23.0, 61.0, 41.0, 624.0, 27.0, 3860.0, 25.0, 74.0, 162.0, 140.0, 580.0, 219.0, 117.0, 394.0, 26.0, 144.0, 785.0, 1198.0, 439.0, 9.0, 84.0, 64.0, 27.0, 94.0, 272.0, 92.0, 11.0, 40.0, 500.0, 665.0, 92.0, 60.0, 9.0, 26.0, 208.0, 869.0, 82.0, 403.0, 44.0, 40.0, 211.0, 298.0, 141.0, 30.0, 79.0, 603.0, 683.0, 261.0, 87.0, 82.0, 230.0, 76.0, 658.0, 1199.0, 7.0, 19.0, 729.0, 54.0, 49.0, 63.0, 264.0, 238.0, 4267.0, 1156.0, 222.0, 707.0, 269.0, 336.0, 75.0, 77.0, 101.0, 1680.0, 1966.0, 142.0, 279.0, 45.0, 28.0, 35.0, 38.0, 205.0, 406.0, 138.0, 206.0, 26.0, 26.0, 62.0, 1693.0, 529.0, 2707.0, 109.0, 97.0, 1532.0, 159.0, 883.0, 225.0, 54.0, 662.0, 96.0, 2142.0, 246.0, 10.0, 17.0, 10.0, 5.0]

# %%
# files = ["Planet99542_Reduced"]
files = subfolders

for file_ in files[:10]:
    file_name = ('forwards/ArielInstrumentTier2/'+file_+'/'+file_+'.hdf5')
    with h5py.File(file_name, 'r') as f:
        fname = (f["ModelParameters/Chemistry/filename"][()])
        mols = f["ModelParameters/Chemistry/active_gases"][()]
        profile = f["Output/Profiles/active_mix_profile"][()] 
        
        fname = fname.decode("utf-8").split("/")[-1]
        plt.title(file_)
        for m,p in zip(mols, profile):
            plt.plot(f["Output/Profiles/pressure_profile"][()], p, label=m)
        plt.annotate(fname, (0.1, 0.1), xycoords="axes fraction")
        plt.xscale("log")
        plt.yscale("log")
        plt.legend()
        plt.savefig("plots/"+file_+"_profile.png")
    # nobs.append(f["Output/Spectra/instrument_nobs"][()])
    
    
for file_ in files:
    file_name = ('forwards/ArielInstrumentTier2/'+file_+'/'+file_+'.hdf5')
    with h5py.File(file_name, 'r') as f:
        fname = (f["ModelParameters/Chemistry/filename"][()])
        mols = f["ModelParameters/Chemistry/active_gases"][()]
        profile = f["Output/Profiles/active_mix_profile"][()] 
        
        fname = fname.decode("utf-8").split("/")[-1]
        for m,p in zip(mols, profile):
            plt.plot(f["Output/Profiles/pressure_profile"][()], p, label=m)
        # plt.annotate(fname, (0.1, 0.1), xycoords="axes fraction")

    plt.title("all of them!")

    plt.xscale("log")
    plt.yscale("log")
    plt.savefig("plots/profile_all.png")
        # plt.legend()
        # plt.show()
