# %%
import numpy as np
import os 
import matplotlib.pyplot as plt
from tqdm import tqdm

directory = "/home/ariel/lorenzo.mugnai/USER_DATA/Alfnoor2/20250226 - NAOJ/week 3/20250314_CompoProfile"
files = [os.path.join(directory, name) for name in os.listdir(directory) if os.path.isfile(os.path.join(directory, name)) if name.endswith(".csv")]
    
for file_ in tqdm(files):
    data = np.loadtxt(file_, skiprows=3, delimiter=',')
    np.savetxt(file_.replace(".csv", ".dat"), data)


directory = "/home/ariel/lorenzo.mugnai/USER_DATA/Alfnoor2/20250226 - NAOJ/week 3/20250314_PTprofile"
files = [os.path.join(directory, name) for name in os.listdir(directory) if os.path.isfile(os.path.join(directory, name)) if name.endswith(".csv")]    
    
for file_ in tqdm(files):
    data = np.loadtxt(file_, skiprows=2, delimiter=',')
    new_fname = file_.replace(".csv", ".dat")
    np.savetxt(file_.replace(".csv", ".dat"), data)
# Out:
# ...
# 100%|██████████| 40/40 [00:00<00:00, 471.04it/s]
